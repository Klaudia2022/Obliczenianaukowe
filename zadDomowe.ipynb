# %% [markdown]
# <a href="https://colab.research.google.com/github/Klaudia2022/Obliczenianaukowe/blob/main/zadDomowe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Tytuł

# %% [markdown]
# #Sekcja 1

# %%
a=input("Podaj swoje imię: ")
print ("Cześć ", a)
# Out:
# Podaj swoje imię: Klaudia
# Cześć  Klaudia

# %% [markdown]
# # Sekcja 2

# %% [markdown]
# ```python
# a=input("Podaj swoje imię: ")
# print("Cześć ", a)
# ```

# %% [markdown]
# # Sekcja 3

# %% [markdown]
# ![16149867_16149864.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Sekcja 4

# %%
import random
def listownik():
  a=0
  while a<10 or a>20:
    a=int(input("Podaj liczbę niemniejszą od 10 i niewiększą od 20: "))
  list=[]
  for i in range(0,a):
    list.append(random.randint(0,10))
  print(list)
  wynik=[]
  for i in list:
    if i  not in wynik:
      wynik.append(i)
  return(len(wynik))

listownik()
# Out:
# Podaj liczbę niemniejszą od 10 i niewiększą od 20: 11
# [6, 8, 0, 9, 0, 10, 8, 8, 4, 0, 3]
# 7
